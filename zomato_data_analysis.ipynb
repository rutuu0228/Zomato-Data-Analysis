# %% [markdown]
# ## Zomato Data Analysis Project

# %%
# Step 1 - Importing Libraries

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# step 2 - creating DataFrame

df = pd.read_csv("Zomato data .csv")

df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
# convert the datatype of column - rate

def handleRate(value):
    value = str(value).split('/')
    value = value[0];
    return float(value)

df['rate'] = df['rate'].apply(handleRate)

df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    str
#  1   online_order                 148 non-null    str
#  2   book_table                   148 non-null    str
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    str
# dtypes: float64(1), int64(2), str(4)
# memory usage: 8.2 KB

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
df.shape
# Out:
# (148, 7)

# %%
df.describe()
# Out:
#              rate        votes  approx_cost(for two people)
# count  148.000000   148.000000                   148.000000
# mean     3.633108   264.810811                   418.243243
# std      0.402271   653.676951                   223.085098
# min      2.600000     0.000000                   100.000000
# 25%      3.300000     6.750000                   200.000000
# 50%      3.700000    43.500000                   400.000000
# 75%      3.900000   221.750000                   600.000000
# max      4.600000  4884.000000                   950.000000

# %%
# Type of resturant majority customers order from 

df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(data= df , x=df['listed_in(type)'], palette='Set2')

plt.xlabel('Type of Resturants')

plt.title('Zomato - Resturants')

plt.show()
# Out:
# C:\Users\rutuu\AppData\Local\Temp\ipykernel_19496\3911955685.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data= df , x=df['listed_in(type)'], palette='Set2')

# %%
#conclusion - Majoity of the returant falls in 'Dinning' category

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
grouped_data = df.groupby('listed_in(type)')['votes'].sum()

result = pd.DataFrame({'vote': grouped_data})

plt.plot(result,c="green",marker='o')

plt.xlabel("Type of Resturant ", c="red" ,size=20)

plt.ylabel("votes",c="red",size=20)
# Out:
# Text(0, 0.5, 'votes')

# %%
# conclusion: Dinning resturants has recieved maximum votes

# %%
grouped_data
# Out:
# listed_in(type)
# Buffet     3028
# Cafes      6434
# Dining    20363
# other      9367
# Name: votes, dtype: int64

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.hist(df['rate'],bins=10)

plt.title('Ratings Distribution')

plt.show()

# %%
# conclusion: the majority resturants recieved ratings from 3.5 to 4

# %%
# Average Order Speding by Couples

df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
couple_data = df['approx_cost(for two people)']

sns.countplot(data = df , x=couple_data ,palette='Set2')
# Out:
# C:\Users\rutuu\AppData\Local\Temp\ipykernel_19496\837383413.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df , x=couple_data ,palette='Set2')
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %%
# conclusion : the mojority of couples prefer returants with an approximate cost of 300 rs.

# %%
# Which mode receives max ratings

df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.figure(figsize=(6,5))

sns.boxplot(data= df, x='online_order', y='rate' , palette='Set2')

plt.title('Resturant mode receiving max rate')
# Out:
# C:\Users\rutuu\AppData\Local\Temp\ipykernel_19496\2968609547.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data= df, x='online_order', y='rate' , palette='Set2')
# Text(0.5, 1.0, 'Resturant mode receiving max rate')

# %%
# conclusion : offline order received lower rating in comparison to online order

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
pivot_table = df.pivot_table(index='listed_in(type)', columns = 'online_order', aggfunc='size' , fill_value = 0)

sns.heatmap(pivot_table, annot= True, cmap='Greens' , fmt='d')

plt.title("Heatmap")

plt.xlabel("Online Order")

plt.ylabel("Listed In(Type)")

plt.show()

# %%
# Conlcusion : Dinning type of Resturants received more offline orders so that Zomato can provide customers with some good offers
